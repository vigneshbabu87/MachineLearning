# %% [markdown]
# # Assignment 06- Data Cleaning

# %% [markdown]
# # Problem Statements

# %% [markdown]
# ### 1.It happens all the time: someone gives you data containing malformed strings,Python, lists and missing data. How do you tidy it up so you can get on with the analysis?

# %% [markdown]
# ### Take this monstrosity as the DataFrame to use in the following puzzles:
# df = pd.DataFrame({'From_To': ['LoNDon_paris', 'MAdrid_miLAN',
# 'londON_StockhOlm',
# 'Budapest_PaRis', 'Brussels_londOn'],
# 'FlightNumber': [10045, np.nan, 10065, np.nan, 10085],
# 'RecentDelays': [[23, 47], [], [24, 43, 87], [13], [67, 32]],
# 'Airline': ['KLM(!)', '<Air France> (12)', '(British Airways. )',
# '12. Air France', '"Swiss Air"']})

# %%
import pandas as pd
import numpy as np

# %%
# Load the data frame
df = pd.DataFrame({'From_To': ['LoNDon_paris', 'MAdrid_miLAN', 'londON_StockhOlm', 'Budapest_PaRis', 'Brussels_londOn'], 'FlightNumber': [10045, np.nan, 10065, np.nan, 10085], 'RecentDelays': [[23, 47], [], [24, 43, 87], [13], [67, 32]], 'Airline': ['KLM(!)', ' (12)', '(British Airways. )', '12. Air France', '"Swiss Air"']})

# %%
#move teh data frame to other variables

Tempdf=df
Tempdf.head()
# Out:
#             From_To  FlightNumber  RecentDelays              Airline
# 0      LoNDon_paris       10045.0      [23, 47]               KLM(!)
# 1      MAdrid_miLAN           NaN            []                 (12)
# 2  londON_StockhOlm       10065.0  [24, 43, 87]  (British Airways. )
# 3    Budapest_PaRis           NaN          [13]       12. Air France
# 4   Brussels_londOn       10085.0      [67, 32]          "Swiss Air"

# %% [markdown]
# ### 1. Some values in the the FlightNumber column are missing. These numbers are meant to increase by 10 with each row so 10055 and 10075 need to be put in place. Fill in these missing numbers and make the column an integer column (instead of a float column).

# %%
Tempdf.dtypes
# Out:
# From_To          object
# FlightNumber    float64
# RecentDelays     object
# Airline          object
# dtype: object

# %%
#Range of flight number columns
Fillflightmissingdata =[x for x in range(10045,10095,10)]
Fillflightmissingdata
# Out:
# [10045, 10055, 10065, 10075, 10085]

# %%
#Tempdf.drop("FlightNo", axis=1, inplace=True)

# %%
#update the flight number missing values and change the column
Tempdf['FlightNumber']= Fillflightmissingdata

Tempdf.head()
# Out:
#             From_To  FlightNumber  RecentDelays              Airline
# 0      LoNDon_paris         10045      [23, 47]               KLM(!)
# 1      MAdrid_miLAN         10055            []                 (12)
# 2  londON_StockhOlm         10065  [24, 43, 87]  (British Airways. )
# 3    Budapest_PaRis         10075          [13]       12. Air France
# 4   Brussels_londOn         10085      [67, 32]          "Swiss Air"

# %% [markdown]
# ### 2. The From_To column would be better as two separate columns! Split each string on the underscore delimiter _ to give a new temporary DataFrame with the correct values. Assign the correct column names to this temporary DataFrame.

# %%
# split the location from and to in teh data frame
Splitlocation = Tempdf["From_To"].str.split("_", n = 1, expand = True) 
  
# making separate first name column from new data frame 
Tempdf["From"]= Splitlocation[0] 
  
# making separate last name column from new data frame 
Tempdf["To"]= Splitlocation[1] 

Tempdf.head()
# Out:
#             From_To  FlightNumber  RecentDelays              Airline  \
# 0      LoNDon_paris         10045      [23, 47]               KLM(!)
# 1      MAdrid_miLAN         10055            []                 (12)
# 2  londON_StockhOlm         10065  [24, 43, 87]  (British Airways. )
# 3    Budapest_PaRis         10075          [13]       12. Air France
# 4   Brussels_londOn         10085      [67, 32]          "Swiss Air"
#
#        From         To
# 0    LoNDon      paris
# 1    MAdrid      miLAN
# 2    londON  StockhOlm
# 3  Budapest      PaRis
# 4  Brussels     londOn

# %% [markdown]
# ### 3. Notice how the capitalisation of the city names is all mixed up in this temporary DataFrame. Standardise the strings so that only the first letter is uppercase (e.g. "londON" should become "London".)

# %%
Tempdf["From"]=Tempdf["From"].str.capitalize()
Tempdf["To"]=Tempdf["To"].str.capitalize()

Tempdf.head()
# Out:
#             From_To  FlightNumber  RecentDelays              Airline  \
# 0      LoNDon_paris         10045      [23, 47]               KLM(!)
# 1      MAdrid_miLAN         10055            []                 (12)
# 2  londON_StockhOlm         10065  [24, 43, 87]  (British Airways. )
# 3    Budapest_PaRis         10075          [13]       12. Air France
# 4   Brussels_londOn         10085      [67, 32]          "Swiss Air"
#
#        From         To
# 0    London      Paris
# 1    Madrid      Milan
# 2    London  Stockholm
# 3  Budapest      Paris
# 4  Brussels     London

# %% [markdown]
# ### 4. Delete the From_To column from df and attach the temporary DataFrame from the previous questions.

# %%
df.head()
# Out:
#             From_To  FlightNumber  RecentDelays              Airline  \
# 0      LoNDon_paris         10045      [23, 47]               KLM(!)
# 1      MAdrid_miLAN         10055            []                 (12)
# 2  londON_StockhOlm         10065  [24, 43, 87]  (British Airways. )
# 3    Budapest_PaRis         10075          [13]       12. Air France
# 4   Brussels_londOn         10085      [67, 32]          "Swiss Air"
#
#        From         To
# 0    London      Paris
# 1    Madrid      Milan
# 2    London  Stockholm
# 3  Budapest      Paris
# 4  Brussels     London

# %%
# delete the  From_To column in data frame

df.drop(columns =["From_To"], inplace = True) 
df.head()
# Out:
#    FlightNumber  RecentDelays              Airline      From         To
# 0         10045      [23, 47]               KLM(!)    London      Paris
# 1         10055            []                 (12)    Madrid      Milan
# 2         10065  [24, 43, 87]  (British Airways. )    London  Stockholm
# 3         10075          [13]       12. Air France  Budapest      Paris
# 4         10085      [67, 32]          "Swiss Air"  Brussels     London

# %%
Tempdf
# Out:
#    FlightNumber  RecentDelays              Airline      From         To
# 0         10045      [23, 47]               KLM(!)    London      Paris
# 1         10055            []                 (12)    Madrid      Milan
# 2         10065  [24, 43, 87]  (British Airways. )    London  Stockholm
# 3         10075          [13]       12. Air France  Budapest      Paris
# 4         10085      [67, 32]          "Swiss Air"  Brussels     London

# %%
#REorder the columns and assign to temporary dataframe
Tempdf=Tempdf[["From","To","FlightNumber","RecentDelays","Airline"]]

Tempdf
# Out:
#        From         To  FlightNumber  RecentDelays              Airline
# 0    London      Paris         10045      [23, 47]               KLM(!)
# 1    Madrid      Milan         10055            []                 (12)
# 2    London  Stockholm         10065  [24, 43, 87]  (British Airways. )
# 3  Budapest      Paris         10075          [13]       12. Air France
# 4  Brussels     London         10085      [67, 32]          "Swiss Air"

# %% [markdown]
# ### 5. In the RecentDelays column, the values have been entered into the DataFrame as a list. We would like each first value in its own column, each second value in its own column, and so on. If there isn't an Nth value, the value should be NaN.
# ### Expand the Series of lists into a DataFrame named delays, rename the columns delay_1, delay_2, etc. and replace the unwanted RecentDelays column in df with delays

# %%
# list down teh series of the delays
delaydf= df["RecentDelays"].apply(pd.Series)
delaydf
# Out:
#       0     1     2
# 0  23.0  47.0   NaN
# 1   NaN   NaN   NaN
# 2  24.0  43.0  87.0
# 3  13.0   NaN   NaN
# 4  67.0  32.0   NaN

# %%
#Assign the delays in dataframe

Tempdf["Delay1"]=delaydf[0]
Tempdf["Delay2"]=delaydf[1]
Tempdf["Delay3"]=delaydf[2]

Tempdf.head()
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# ...

# %% [markdown]
# ### Expand the Series of lists into a DataFrame named delays, rename the columns delay_1, delay_2, etc. and replace the unwanted RecentDelays column in df with delays

# %%
Tempdf.drop(columns =["RecentDelays"], inplace = True) 
Tempdf.head()
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\frame.py:3997: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   errors=errors,
#        From         To  FlightNumber              Airline  Delay1  Delay2  \
# 0    London      Paris         10045               KLM(!)    23.0    47.0
# 1    Madrid      Milan         10055                 (12)     NaN     NaN
# 2    London  Stockholm         10065  (British Airways. )    24.0    43.0
# 3  Budapest      Paris         10075       12. Air France    13.0     NaN
# 4  Brussels     London         10085          "Swiss Air"    67.0    32.0
#
#    Delay3
# 0     NaN
# 1     NaN
# 2    87.0
# 3     NaN
# 4     NaN

# %%
Tempdf['Airline'].replace(regex=True, inplace=True, to_replace=r'[^a-zA-Z\_+]',value=r'')
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\generic.py:6746: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._update_inplace(new_data)

# %%
Tempdf.head()
# Out:
#        From         To  FlightNumber         Airline  Delay1  Delay2  Delay3
# 0    London      Paris         10045             KLM    23.0    47.0     NaN
# 1    Madrid      Milan         10055                     NaN     NaN     NaN
# 2    London  Stockholm         10065  BritishAirways    24.0    43.0    87.0
# 3  Budapest      Paris         10075       AirFrance    13.0     NaN     NaN
# 4  Brussels     London         10085        SwissAir    67.0    32.0     NaN
